# %%
dbutils.notebook.run("./dim_dates", timeout_seconds=600)
dbutils.notebook.run("./fact_budget_vs_actual", timeout_seconds=600)
dbutils.notebook.run("./fact_event_revenue", timeout_seconds=600)
dbutils.notebook.run("./fact_ticket_sales", timeout_seconds=600)
