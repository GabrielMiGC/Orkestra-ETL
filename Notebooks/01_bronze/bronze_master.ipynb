# %%
dbutils.notebook.run("/Users/gabriel_gm23@hotmail.com/Orkestra-ETL/Notebooks/01_bronze/01_load_seeds", timeout_seconds=600)
dbutils.notebook.run("/Users/gabriel_gm23@hotmail.com/Orkestra-ETL/Notebooks/01_bronze/ingest_events", timeout_seconds=600)
