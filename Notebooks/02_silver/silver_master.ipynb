# %%
# executa todos os notebooks da camada silver
dbutils.notebook.run("./silver_commerce", timeout_seconds=600)
dbutils.notebook.run("./silver_events", timeout_seconds=600)
dbutils.notebook.run("./silver_users_anon", timeout_seconds=600)
dbutils.notebook.run("./silver_expenses", timeout_seconds=600)
dbutils.notebook.run("./silver_ticket_orders", timeout_seconds=600)
