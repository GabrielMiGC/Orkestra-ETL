# %%
dbutils.notebook.run("./features_consumer_behavior", timeout_seconds=600)
dbutils.notebook.run("./features_demand_signals", timeout_seconds=600)
dbutils.notebook.run("./features_event_profile", timeout_seconds=600)
