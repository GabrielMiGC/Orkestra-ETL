# %%
# Executa os outros notebooks de setup
dbutils.notebook.run("00_cluster_setup", timeout_seconds=900) # maior tempo pois temos muitos arquivos csv para upload
dbutils.notebook.run("00_setup_databases", timeout_seconds=600)
